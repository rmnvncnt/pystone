# %%
import json

# %%
with open('cards.json') as file:
    data = json.load(file)

# %%
data[0]
# Out:
# {'artist': 'Paul Mafayon',
#  'cardClass': 'WARLOCK',
#  'collectible': True,
#  'cost': 6,
#  'dbfId': 2632,
#  'flavor': 'A prime example of lose-lose negotiating.',
#  'id': 'AT_025',
#  'name': 'Dark Bargain',
#  'playRequirements': {'REQ_MINIMUM_ENEMY_MINIONS': 2},
#  'playerClass': 'WARLOCK',
#  'rarity': 'EPIC',
#  'set': 'TGT',
#  'text': 'Destroy 2 random enemy minions. Discard 2 random cards.',
#  'type': 'SPELL'}

# %%
data[0]['name']
# Out:
# 'Dark Bargain'

# %%
for i in data:
    if i.get('name') == 'Dark Bargain':
        print (i['dbfId'])
    else:
        print ('pass')
# Out:
# 2632
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# ...
